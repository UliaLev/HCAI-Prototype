# %%
import pandas as pd

recipes = pd.read_json("data/raw/recipes_images.json")

print(recipes.columns)
print(recipes.head())
# Out:
# Index(['title', 'description', 'ingredients', 'instructions', 'cooking_time',
#        'servings', 'ratings', 'tags', 'publish_date', 'image_filename'],
#       dtype='str')
#                                            title  \
# 0         Pasta-Shell Risotto with Broccoli Rabe
# 1  Penne with Shrimp, Red Onion, and Goat Cheese
# 2                    Roasted Salmon with Lentils
# 3                           Radicchio with Bacon
# 4                   Louisiana Deviled Crab Cakes
#
#                                          description  \
# 0  Slowly cooking the pasta risotto-style by ladl...
# 1                                                NaN
# 2  The cooking time for lentils can vary widely d...
# 3  Closely related in flavor and spirit to the cl...
# 4  These crab cakes are flavored with the "holy t...
#
#                                          ingredients  \
# 0  [1 quart reduced-sodium chicken broth, 1 quart...
# 1  [1 pound whole grain penne, Kosher salt, 3 tab...
# ...
